# %%
# Quantitative Predictors:
# 1. mpg
# 2. cylinders
# 3. displacement
# 4. horsepower
# 5. weight
# 6. acceleration

# Qualitative Predictor:
# 1. name
# 2. year
# 3. origin

# %%
import numpy as np
import pandas as pd
Auto = pd.read_csv("Auto.csv")
Auto
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        130    3504          12.0    70
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0         86    2790          15.6    82
# 393  44.0          4          97.0         52    2130          24.6    82
# 394  32.0          4         135.0         84    2295          11.6    82
# 395  28.0          4         120.0         79    2625          18.6    82
# 396  31.0          4         119.0         82    2720          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# ...

# %%
Auto_cleaned = Auto.dropna(subset=['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration'])
Auto_cleaned
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        130    3504          12.0    70
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0         86    2790          15.6    82
# 393  44.0          4          97.0         52    2130          24.6    82
# 394  32.0          4         135.0         84    2295          11.6    82
# 395  28.0          4         120.0         79    2625          18.6    82
# 396  31.0          4         119.0         82    2720          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# ...

# %%
Auto_cleaned['horsepower'] = pd.to_numeric(Auto_cleaned['horsepower'], errors='coerce')
Auto_cleaned = Auto_cleaned.dropna(subset=['horsepower'])
Auto_cleaned
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0       130.0    3504          12.0    70
# 1    15.0          8         350.0       165.0    3693          11.5    70
# 2    18.0          8         318.0       150.0    3436          11.0    70
# 3    16.0          8         304.0       150.0    3433          12.0    70
# 4    17.0          8         302.0       140.0    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 392  27.0          4         140.0        86.0    2790          15.6    82
# 393  44.0          4          97.0        52.0    2130          24.6    82
# 394  32.0          4         135.0        84.0    2295          11.6    82
# 395  28.0          4         120.0        79.0    2625          18.6    82
# 396  31.0          4         119.0        82.0    2720          19.4    82
#
#      origin                       name
# ...

# %%
numpy_array=Auto_cleaned[['mpg','cylinders','displacement','horsepower','weight','acceleration']].values
numpy_array
# Out:
# array([[  18. ,    8. ,  307. ,  130. , 3504. ,   12. ],
#        [  15. ,    8. ,  350. ,  165. , 3693. ,   11.5],
#        [  18. ,    8. ,  318. ,  150. , 3436. ,   11. ],
#        ...,
#        [  32. ,    4. ,  135. ,   84. , 2295. ,   11.6],
#        [  28. ,    4. ,  120. ,   79. , 2625. ,   18.6],
#        [  31. ,    4. ,  119. ,   82. , 2720. ,   19.4]])

# %%
max_values_columnwise = np.max(numpy_array, axis=0)
max_values_columnwise
# Out:
# array([  46.6,    8. ,  455. ,  230. , 5140. ,   24.8])

# %%
min_values_columnwise = np.min(numpy_array, axis=0)
min_values_columnwise
# Out:
# array([   9.,    3.,   68.,   46., 1613.,    8.])

# %%
range=pd.DataFrame({'Minimum Value':min_values_columnwise,'Maximum value':max_values_columnwise}, 
                   index=['mpg','cylinders','displacement','horsepower','weight','acceleration'])
range
# Out:
#               Minimum Value  Maximum value
# mpg                     9.0           46.6
# cylinders               3.0            8.0
# displacement           68.0          455.0
# horsepower             46.0          230.0
# weight               1613.0         5140.0
# acceleration            8.0           24.8

# %%
mean=np.mean(numpy_array, axis=0)
mean
# Out:
# array([  23.44591837,    5.47193878,  194.4119898 ,  104.46938776,
#        2977.58418367,   15.54132653])

# %%
std_dev=np.std(numpy_array, axis=0)
std_dev
# Out:
# array([  7.79504576,   1.70360611, 104.51044418,  38.44203271,
#        848.31844657,   2.75534291])

# %%
Qc=pd.DataFrame({'Mean':mean, 'Standard Deviation':std_dev}, index=['mpg','cylinders','displacement','horsepower','weight','acceleration'])
Qc
# Out:
#                      Mean  Standard Deviation
# mpg             23.445918            7.795046
# cylinders        5.471939            1.703606
# displacement   194.411990          104.510444
# horsepower     104.469388           38.442033
# weight        2977.584184          848.318447
# acceleration    15.541327            2.755343

# %%
numpy_array_rem=np.delete(numpy_array, np.s_[9:85], axis=0)
numpy_array_rem
# Out:
# array([[  18. ,    8. ,  307. ,  130. , 3504. ,   12. ],
#        [  15. ,    8. ,  350. ,  165. , 3693. ,   11.5],
#        [  18. ,    8. ,  318. ,  150. , 3436. ,   11. ],
#        ...,
#        [  32. ,    4. ,  135. ,   84. , 2295. ,   11.6],
#        [  28. ,    4. ,  120. ,   79. , 2625. ,   18.6],
#        [  31. ,    4. ,  119. ,   82. , 2720. ,   19.4]])

# %%
max_values_columnwise_rem = np.max(numpy_array_rem, axis=0)
max_values_columnwise_rem
# Out:
# array([  46.6,    8. ,  455. ,  230. , 4997. ,   24.8])

# %%
min_values_columnwise_rem = np.min(numpy_array_rem, axis=0)
min_values_columnwise_rem
# Out:
# array([  11. ,    3. ,   68. ,   46. , 1649. ,    8.5])

# %%
range=pd.DataFrame({'Minimum Value':min_values_columnwise_rem,'Maximum value':max_values_columnwise_rem}, index=['mpg','cylinders','displacement','horsepower','weight','acceleration'])
range
# Out:
#               Minimum Value  Maximum value
# mpg                    11.0           46.6
# cylinders               3.0            8.0
# displacement           68.0          455.0
# horsepower             46.0          230.0
# weight               1649.0         4997.0
# acceleration            8.5           24.8

# %%
mean_rem=np.mean(numpy_array_rem, axis=0)
mean_rem
# Out:
# array([  24.40443038,    5.37341772,  187.24050633,  100.72151899,
#        2935.97151899,   15.72689873])

# %%
std_dev_rem=np.std(numpy_array_rem, axis=0)
std_dev_rem
# Out:
# array([  7.85482473,   1.65155921,  99.52052332,  35.65230715,
#        810.0154881 ,   2.68945512])

# %%
Qd=pd.DataFrame({'Mean':mean_rem, 'Standard Deviation':std_dev_rem}, index=['mpg','cylinders','displacement','horsepower','weight','acceleration'])
Qd
# Out:
#                      Mean  Standard Deviation
# mpg             24.404430            7.854825
# cylinders        5.373418            1.651559
# displacement   187.240506           99.520523
# horsepower     100.721519           35.652307
# weight        2935.971519          810.015488
# acceleration    15.726899            2.689455

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(nrows=3, ncols=2,figsize=(20,20))

# %%
axes[0,0].plot(numpy_array[:,0])
axes[0,0].set_title('mpg')
axes[0,1].plot(numpy_array[:,1])
axes[0,1].set_title('cylinders')
axes[1,0].plot(numpy_array[:,2])
axes[1,0].set_title('displacement')
axes[1,1].plot(numpy_array[:,3])
axes[1,1].set_title('horspower')
axes[2,0].plot(numpy_array[:,4])
axes[2,0].set_title('weight')
axes[2,1].plot(numpy_array[:,5])
axes[2,1].set_title('acceleration')
fig

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style='ticks')
sns.pairplot(Auto_cleaned[['mpg','cylinders','displacement','horsepower','weight','acceleration']])
plt.show()
